# %% [markdown]
# # 데이터 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
anime_stock_returns_csv = './sample-data/anime/anime_stock_returns.csv'
anime_stock_returns_df = pd.read_csv(anime_stock_returns_csv, index_col=0)
ax = anime_stock_returns_df.plot()
ax.set_title('stock returns')
plt.show()

# %% [markdown]
# ### Y축 범위가 다른 경우

# %%
anime_stock_price_csv = './sample-data/anime/anime_stock_price.csv'
df = pd.read_csv(anime_stock_price_csv, index_col=0, parse_dates=['Date'])

fig = plt.figure(figsize = (10, 4))
ax1 = fig.add_subplot(111)

ax1.plot(df.index, df['TOEI ANIMATION'], color='b', label='TOEI ANIMATION')

ax2 = ax1.twinx()
ax2.plot(df.index, df['IG Port'], color='g', label='IG Port')

# 제목 설정, 축과 축 레이블
ax1.set_title('anime stock price')
ax1.set_xlabel('time')
ax1.set_ylabel('TOEI ANIMATION')
ax2.set_ylabel('IG Port')

#범례 설정
ax1.legend(loc=1)
ax2.legend(loc=2)
plt.show()

# %% [markdown]
# ### 복수의 그림에 분할하는 방법

# %%
anime_stock_price_csv = './sample-data/anime/anime_stock_price.csv'
anime_stock_price_df = pd.read_csv(anime_stock_price_csv, index_col=0)

ax1, ax2 = anime_stock_price_df.plot(subplots=True)
ax1.set_title('subplot1')
ax2.set_title('subplot2')
plt.show()

# %% [markdown]
# ### 산포도 그래프

# %%
anime_master_csv = './sample-data/anime/anime_master.csv'
anime_master_df = pd.read_csv(anime_master_csv)

ax = anime_master_df.plot.scatter(x='members', y='rating')
ax.set_title('Scatter')
plt.show()

# %% [markdown]
# ### 히스토그램

# %%
ax = anime_master_df['rating'].hist(bins=100)
ax.set_title('Histogram')
plt.show()

# %% [markdown]
# ### 상자수염 그래프

# %%
anime_genre_top10_pivoted_csv = './sample-data/anime/anime_genre_top10_pivoted.csv'
anime_genre_top10_pivoted_df = pd.read_csv(anime_genre_top10_pivoted_csv)

ax = anime_genre_top10_pivoted_df.plot.box()
ax.set_title('Box plot')
plt.show()
